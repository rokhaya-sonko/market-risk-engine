# %% [markdown]
# ## Rates Risk — Bond + Swap + DV01 Hedging
#
# #### Objectives
# - Build / use a yield curve (discount factors)
# - Price bonds and a plain vanilla swap (as risk inputs)
# - Compute DV01 / PV01 (bump-and-reprice)
# - Hedge interest-rate risk using DV01 (hedge ratio)
# - Validate hedge with parallel and twist shocks
#
# #### Key outputs
# - DV01 (total + bucket)
# - Hedged vs unhedged PnL under rate shocks
# - Short market risk commentary and limitations
